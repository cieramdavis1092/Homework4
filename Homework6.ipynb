# %% [markdown]
# <a href="https://colab.research.google.com/github/cieramdavis1092/Homework4/blob/main/Homework6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

words = ['ham', 'lord', 'haue', 'king', 'shall', 'hamlet', 'come', 'thou', 'let', 'good', 'hor', 'thy', 'may', 'enter', 'oh', 'like', 'well', 'know', 'would', 'selfe']
counts = [340, 212, 175, 174, 107, 107, 106, 105, 104, 99, 95, 90, 86, 84, 81, 79, 73, 71, 69, 68]

plt.bar(words, counts)
plt.xlabel('word')
plt.xticks(rotation=90)
plt.show()

import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = """
end Osr owne VS hand good Lord say faire glue Ophelia life two go great finde true This time da Oh Enter take Mar Noble keepe Player ord Poore are heart Denmarket within i'th' Laertes thought vp dead Hor thousoule W111 cause euen King world Project Gutenberg deere Evertue right Qu feare whose God Ile done may thine Nature earth made please Politis mine Lord Ham Hamletnow therefore eye one know Mother Play without part haue pray doth shew sent State tongue Spirit meane stand doe many Fatherhath madne much hold fit Polon vse amwell et breath call live beare speech Friend winde S1 reared must thy come iloues ext Nay Leaue thee selfe ha himselfe last Laer away drinke see Kin foll follow hee Sword
"""

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
